# %%
from pstats import Stats
from pathlib import Path

# %%
PSTATS_PATH = "../prof/combined.prof"

# %%
stats = Stats(PSTATS_PATH)

# %%
stats.strip_dirs().sort_stats("cumulative").print_stats(20)
# Out:
# Fri Jan  2 16:25:28 2026    ../prof/combined.prof
#
#          7753084 function calls (7671876 primitive calls) in 3.940 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1733 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     13/10    0.000    0.000    3.941    0.394 runner.py:115(pytest_runtest_protocol)
#     13/10    0.001    0.000    3.940    0.394 runner.py:123(runtestprotocol)
#     33/30    0.000    0.000    3.938    0.131 runner.py:231(call_and_report)
#   158/110    0.000    0.000    3.938    0.036 _hooks.py:497(__call__)
#   158/110    0.000    0.000    3.937    0.036 _manager.py:111(_hookexec)
#   155/110    0.001    0.000    3.937    0.036 _callers.py:76(_multicall)
#     33/30    0.000    0.000    3.934    0.131 runner.py:332(from_call)
#     33/30    0.000    0.000    3.934    0.131 runner.py:245(<lambda>)
#        10    0.000    0.000    2.669    0.267 runner.py:168(pytest_runtest_call)
#        10    0.000    0.000    2.664    0.266 python.py:1718(runtest)
#        10    0.001    0.000    2.663    0.266 python.py:159(pytest_pyfunc_call)
#        76    0.018    0.000    2.499    0.033 cparser.py:307(_parse)
#        76    0.000    0.000    2.434    0.032 c_parser.py:130(parse)
#        76    0.000    0.000    2.434    0.032 yacc.py:323(parse)
#        76    0.665    0.009    2.434    0.032 yacc.py:1001(parseopt_notrack)
#       952    0.001    0.000    2.312    0.002 api.py:180(_typeof)
#        75    0.000    0.000    2.311    0.031 api.py:162(_typeof_locked)
#        75    0.000    0.000    2.308    0.031 cparser.py:560(parse_type)
#        75    0.001    0.000    2.308    0.031 cparser.py:563(parse_type_and_quals)
#       824    0.001    0.000    1.901    0.002 api.py:242(new)

# %%
stats.strip_dirs().sort_stats("tottime").print_stats(20)
# Out:
# Fri Jan  2 16:25:28 2026    ../prof/combined.prof
#
#          7753084 function calls (7671876 primitive calls) in 3.940 seconds
#
#    Ordered by: internal time
#    List reduced from 1733 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        76    0.665    0.009    2.434    0.032 yacc.py:1001(parseopt_notrack)
#        57    0.432    0.008    0.432    0.008 {method 'astype' of 'numpy.ndarray' objects}
#    164781    0.349    0.000    0.349    0.000 {method 'match' of 're.Pattern' objects}
#       976    0.230    0.000    0.230    0.000 {method 'encode' of 'ImagingEncoder' objects}
#    126941    0.153    0.000    0.619    0.000 lex.py:305(token)
#        81    0.129    0.002    0.129    0.002 {method 'decode' of 'ImagingDecoder' objects}
#   1439368    0.126    0.000    0.126    0.000 {method 'append' of 'list' objects}
#    678509    0.114    0.000    0.171    0.000 yacc.py:240(__getitem__)
#   1059757    0.094    0.000    0.099    0.000 {built-in method builtins.isinstance}
#    819264    0.093    0.000    0.093    0.000 {method 'get' of 'dict' objects}
#         9    0.087    0.010    0.096    0.011 images.py:112(convert_linear_to_srgb)
#  1026/968    0.072    0.000    0.076    0.000 _helpers.py:352(proxy_func)
#     30839    0.070    0.000    0.216    0.000 c_parser.py:368(_build_declarations)
#         9    0.060    0.007    0.131    0.015 images.py:19(compute_psnr)
#     63806    0.054    0.000    0.150    0.000 plyparser.py:55(_token_coord)
#         6    0.052    0.009    0.085    0.014 _helpers.py:85(get_wgpu_instance)
#         5    0.048    0.010    0.156    0.031 loader.py:65(load_rgba_image)
#    523692    0.039    0.000    0.039    0.000 yacc.py:248(__setitem__)
#    126941    0.039    0.000    0.658    0.000 c_lexer.py:75(token)
#     31095    0.036    0.000    0.046    0.000 c_parser.py:299(_fix_decl_name_type)
